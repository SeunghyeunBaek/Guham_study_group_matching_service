# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# 참고사이트 : https://github.com/susanli2016/NLP-with-Python/blob/master/Fuzzy%20String%20Matching.ipynb

# %%
from random import *
import pandas as pd
import numpy as np
from pandas import DataFrame
# %matplotlib inline
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# d:\pl\python\python37\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# generate 100 dummy data
hash_tags = ['r', 'python', 'java', 'c', 'ruby']
tmp_dict = {
    'user_id':[],
    'hash_tags':[]
}

# 1 dummy has 1-5 tags
for i in range(100):
    n_tags = randint(1,5)
    random_tags = sample(hash_tags, n_tags)
    tmp_dict['user_id'].append(i)
    tmp_dict['hash_tags'].append(random_tags)

tmp_df = pd.DataFrame.from_dict(tmp_dict)
tmp_df.head(10)
# Out:
#    user_id                   hash_tags
# 0        0                [ruby, r, c]
# 1        1          [ruby, c, r, java]
# 2        2                [c, ruby, r]
# 3        3             [ruby, java, c]
# 4        4  [java, python, ruby, c, r]
# 5        5                [ruby, java]
# 6        6  [c, java, python, r, ruby]
# 7        7              [r, c, python]
# 8        8  [java, c, ruby, python, r]
# 9        9           [c, python, java]

# %%
def sort_and_make_string(hash_tag_list):
    hash_tag_list.sort()
    return ' '.join(hash_tag_list)
    
    
def get_ratio(my_hash_tags, ur_hash_tags):
    # 나와 상대방의 해시태그를 알파벳 순으로 정렬한다.
    # 나와 상대방의 해시태그를 스트링으로 변환한다.
    my_hash_str = sort_and_make_string(my_hash_tags)
    ur_hash_str = sort_and_make_string(ur_hash_tags)
    # fuzzy match ratio 반환
    return fuzz.ratio(my_hash_str, ur_hash_str)

# %%
my_tag = ['r', 'python']
tmp_df['fuzzy_ratio'] = tmp_df['hash_tags'].apply(lambda ur_tag: get_ratio(my_tag, ur_tag))

# %%
# fuzzy_ratio 순으로 내림차순 정렬
tmp_df.sort_values(by=['fuzzy_ratio'], ascending=False)
# Out:
#     user_id             hash_tags  fuzzy_ratio
# 38       38           [python, r]          100
# 66       66           [python, r]          100
# 92       92           [python, r]          100
# 31       31           [python, r]          100
# 56       56        [c, python, r]           89
# 83       83        [c, python, r]           89
# 7         7        [c, python, r]           89
# 54       54        [c, python, r]           89
# 69       69              [python]           86
# 77       77              [python]           86
# 62       62              [python]           86
# 17       17        [python, ruby]           84
# 13       13        [python, ruby]           84
# 43       43        [python, ruby]           84
# 87       87        [python, ruby]           84
# 26       26     [python, r, ruby]           76
# 72       72     [python, r, ruby]           76
# 86       86     [c, python, ruby]           76
# 11       11     [python, r, ruby]           76
# 57       57     [python, r, ruby]           76
# 67       67           [c, python]           75
# 91       91  [c, java, python, r]           70
# 46       46  [c, python, r, ruby]           70
# 47       47  [c, python, r, ruby]           70
# 95       95  [c, java, python, r]           70
# 59       59  [c, python, r, ruby]           70
# 44       44  [java, python, ruby]           67
# 28       28  [java, python, ruby]           67
# 55       55  [java, python, ruby]           67
# 96       96  [java, python, ruby]           67
# ..      ...                   ...          ...
# 75       75          [java, ruby]           24
# 50       50          [java, ruby]           24
# 65       65                   [r]           22
# 34       34                   [r]           22
# 41       41                   [r]           22
# 25       25                   [r]           22
# 63       63                   [r]           22
# 3         3       [c, java, ruby]           21
# 90       90       [java, r, ruby]           21
# 20       20       [java, r, ruby]           21
# 61       61       [c, java, ruby]           21
# 73       73       [java, r, ruby]           21
# 70       70    [c, java, r, ruby]           19
# 1         1    [c, java, r, ruby]           19
# 48       48                [ruby]           17
# 29       29                [ruby]           17
# 98       98             [c, java]           14
# 14       14             [c, java]           14
# 30       30             [c, java]           14
# 39       39             [c, java]           14
# 18       18                [java]            0
# 19       19                [java]            0
# 49       49                [java]            0
# 42       42                [java]            0
# 93       93                   [c]            0
# 12       12                   [c]            0
# 85       85                [java]            0
# 52       52                [java]            0
# 58       58                   [c]            0
# 78       78                [java]            0
#
# [100 rows x 3 columns]
